# %% [markdown]
# # Machine Learning Tutorial Python - 1: Linear Regression Single Variable
#
# In this tutorial we will predict home prices using **linear regression.** We use training data that has home **_areas in square feet and corresponding prices_** and train a __linear regression__ model using **_sklearn linear regression class._** Later on predict method is used on **_linear regression_** object to make actual forecast.
#
#
# Given these home prices.... please find out the prices of homes whose area is,
# 1. 3300 square feet
# 2. 5000 square feet
#
# Code: https://github.com/codebasics/py/tree/master/ML/1_linear_reg <br>
# Credit: https://www.youtube.com/watch?v=8jazNUpO3lQ&list=PLeo1K3hjS3uvCeTYTeyfe0-rN5r8zn9rw&index=2 <br>
# #### Owner: Codebasics

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Machine Learning With Python: Linear Regression With One Variable
# ### Sample problem of predicting home price in monroe, new jersey (USA) <br>
# Below table represents current home prices in monroe township based on square feet area, new jersey

# %% [markdown]
# ## Import all the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model # scikit learn

# %% [markdown]
# ## load or read the csv file using pandas

# %%
df = pd.read_csv("homeprices.csv")
df.head()
# Out:
#    area   price
# 0  1200  550000
# 1  1600  590000
# 2  2000  600000
# 3  2600  640000
# 4  3200  700000

# %% [markdown]
# **Problem Statement:** Given above data build a **machine learning model** that can predict **_home prices based on square feet area_**
#
# You can represent values in above table as a **scatter plot** (values are shown in red markers). After that one can draw a straight line that best fits values on chart.

# %% [markdown]
# ## plot the scatter plot for this file

# %%
#%matplotlib inline
plt.xlabel('area (sqr ft)',fontsize=16)
plt.ylabel('price (US$)',fontsize=16)
plt.scatter(df.area, df.price, color='red', marker='+')
#plt.plot(df.area,reg.predict(df[['areas']]),color='blue')
plt.title('Area vs Price',fontsize=20)
plt.legend(title='house price graph',loc='upper center')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## creating new dataframe from the previous and drop 'price' for 2d array

# %%
#new_df = df.drop('price',axis='columns')
new_df = df.drop(df[['price']], axis='columns')
new_df.head()
# Out:
#    area
# 0  1200
# 1  1600
# 2  2000
# 3  2600
# 4  3200

# %%
price = df[['price']]
price.head()
# Out:
#     price
# 0  550000
# 1  590000
# 2  600000
# 3  640000
# 4  700000

# %% [markdown]
# ## create linear model instance from linear regression method

# %%
model = linear_model.LinearRegression()
model.fit(new_df, df.price) # training the linear regression model
#model.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %% [markdown]
# #### (1) Predict price of a home with area = 3300 sqr ft

# %%
model.predict([[3300]])
# Out:
# array([698999.5908347])

# %% [markdown]
# ## train the model by using fit

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# array([698999.5908347])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## y = m * x + b
# #### dependent variable = coefficient * independent variable + intercept<br>
# #### price = slope * area + intercept

# %%
reg.coef_
# Out:
# array([70.35597381])

# %%
reg.intercept_
# Out:
# 466824.8772504091

# %%
70.35597381 * 3300 + 466824.8772504092
# Out:
# 698999.5908234091

# %% [markdown]
# #### (2) Predict price of a home with area = 5000 sqr ft

# %%
reg.predict([[5000]])
# Out:
# array([818604.74631751])

# %%
70.35597381 * 5000 + 466824.8772504092
# Out:
# 818604.7463004092

# %%
# %matplotlib inline
plt.xlabel('area (sqr ft)', fontsize=16)
plt.ylabel('price (US$)', fontsize=16)
plt.scatter(df.area, df.price, color='red', marker='+')
plt.plot(df.area, reg.predict(df[["area"]]), color='blue')

# %%
area_df = pd.read_csv("areas.csv")
#area_df
area_df.head(3)
# Out:
#    area
# 0  1200
# 1  1600
# 2  2000

# %%
price_df = reg.predict(area_df)
area_df['prices'] = price_df # nothing but adding into the same matrix
price_df
# Out:
# array([551252.04582651, 579394.43535188, 607536.82487725, 635679.21440262,
#        663821.60392799, 691963.99345336, 720106.38297872, 748248.77250409,
#        776391.16202946, 804533.55155483])

# %% [markdown]
# ## Generate a CSV file with the list of home price predictions

# %%
#area_df.to_csv("areas.csv") csv file with index
area_df.to_csv("prediction.csv", index=False) #csv file without index
area_df.head()
# Out:
#    area         prices
# 0  1200  551252.045827
# 1  1600  579394.435352
# 2  2000  607536.824877
# 3  2400  635679.214403
# 4  2800  663821.603928

# %%
reg = linear_model.LinearRegression()
reg.fit(area_df[['area']], area_df['prices'])
area_df['prices'].head()
# Out:
# 0    551252.045827
# 1    579394.435352
# 2    607536.824877
# 3    635679.214403
# 4    663821.603928
# Name: prices, dtype: float64

# %%
area_df[['area']].head()
# Out:
#    area
# 0  1200
# 1  1600
# 2  2000
# 3  2400
# 4  2800

# %%
area_df.head()
# Out:
#    area         prices
# 0  1200  551252.045827
# 1  1600  579394.435352
# 2  2000  607536.824877
# 3  2400  635679.214403
# 4  2800  663821.603928

# %%
# %matplotlib inline
plt.xlabel('area (sqr ft)',fontsize=20)
plt.ylabel('price (US$)',fontsize=20)
plt.scatter(area_df.area,area_df['prices'],color='red',marker='+')
plt.plot(area_df.area, area_df['prices'], color='blue')

# %% [markdown]
# #### Exercise
# Predict **canada's per capita income** in year 2020. There is an exercise folder here on github at same level as this notebook, download that and you will find **_canada_per_capita_income.csv_** file. Using this build a **regression model** and predict the **_per capita income_** of canadian citizens in year 2020
#
# #### Answer
# 41288.69409442
