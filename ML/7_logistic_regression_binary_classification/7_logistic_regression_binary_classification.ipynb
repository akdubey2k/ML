# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('insurance.csv')
df.head()
# Out:
#    age  buy_insurance
# 0   22              0
# 1   25              0
# 2   47              1
# 3   52              0
# 4   46              1

# %%
# %matplotlib inline
plt.scatter(df['age'], df['buy_insurance'], marker='+', color='red')
plt.xlabel('age', fontsize=12)
plt.ylabel('insurance cover(0/1)', fontsize=12)
# Out:
# Text(0, 0.5, 'insurance cover(0/1)')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df['buy_insurance'], test_size=0.2)
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 14   49
# 9    61
# 11   28
# 7    60
# 1    25
# 18   19

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1, 1, 0, 1, 0, 0], dtype=int64)

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
model.predict_proba(X_test)
# Out:
# array([[0.22893812, 0.77106188],
#        [0.06955329, 0.93044671],
#        [0.76841427, 0.23158573],
#        [0.07736968, 0.92263032],
#        [0.82407337, 0.17592663],
#        [0.90324571, 0.09675429]])

# %%
coef = model.coef_
inter = model.intercept_

# %%
import math
def sigmoid(x):
    return (1/(1 + math.exp(-x)))
            
def pred(age):
    z = coef * age + inter
    y = sigmoid(z)
    return y

# %%
pred(58)
# Out:
# 0.904543341078509

# %% [markdown]
# ### <font color='blue'>Relation between training data without a trained model

# %%
# %matplotlib inline
plt.scatter(df['age'], df['buy_insurance'], marker='+', color='red')
plt.xlabel('age', fontsize=12)
plt.ylabel('insurance cover(0/1)', fontsize=12)
plt.plot(X_train, y_train, color='blue')

# %% [markdown]
# ### <font color='green'>Relation between testing data without a trained model

# %%
# %matplotlib inline
plt.scatter(df['age'], df['buy_insurance'], marker='+', color='red')
plt.xlabel('age', fontsize=12)
plt.ylabel('insurance cover(0/1)', fontsize=12)
plt.plot(X_test, y_test, color='green')

# %% [markdown]
# ### <font color='orange'>Relation between testing data with trained model

# %%
# %matplotlib inline
plt.scatter(df['age'], df['buy_insurance'], marker='+', color='red')
plt.xlabel('age', fontsize=12)
plt.ylabel('insurance cover(0/1)', fontsize=12)
plt.plot(X_test, y_pred, color='orange')
