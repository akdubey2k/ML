# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('insurance.csv')
df.head()
# Out:
#    age  buy_insurance
# 0   22              0
# 1   25              0
# 2   47              1
# 3   52              0
# 4   46              1

# %%
plt.scatter(df['age'], df['buy_insurance'], marker='+', color='red')
plt.xlabel('age', fontsize=12)
plt.ylabel('insurance cover(0/1)', fontsize=12)
# Out:
# Text(0, 0.5, 'insurance cover(0/1)')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df['buy_insurance'], test_size=0.2)
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 2    47
# 5    56
# 1    25
# 15   55
# 25   54
# 17   58

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1, 1, 0, 1, 1, 1], dtype=int64)

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
model.predict_proba(X_test)
# Out:
# array([[0.32759986, 0.67240014],
#        [0.15006402, 0.84993598],
#        [0.853478  , 0.146522  ],
#        [0.16502332, 0.83497668],
#        [0.18115601, 0.81884399],
#        [0.12350351, 0.87649649]])

# %%
coef = model.coef_
inter = model.intercept_

# %%
import math
def sigmoid(x):
    return (1/(1 + math.exp(-x)))
            
def pred(age):
    z = coef * age + inter
    y = sigmoid(z)
    return y

# %%
pred(58)
# Out:
# 0.8764964879930909
