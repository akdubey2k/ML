# %% [markdown]
# Download employee retention dataset from here: https://www.kaggle.com/giripujar/hr-analytics.
#
# 1. Now do some exploratory data analysis to figure out which variables have direct and clear impact on employee retention (i.e. whether they leave the company or continue to work)
# 2. Plot bar charts showing impact of employee salaries on retention
# 3. Plot bar charts showing corelation between department and employee retention
# 4. Now build logistic regression model using variables that were narrowed down in step 1
# 5. Measure the accuracy of the model

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Hr_analytic_data.csv')
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
# df.empty

# %%
# df.isnull().head()

# %%
np.where(pd.isnull(df))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
# np.where(pd.isna(df))

# %%
# %matplotlib inline
# fig1 = plt.figure(figsize=(6,8))
# plt.bar(df.salary, df.left, color='maroon',width=0.4)
# plt.grid()

# %%
# df.Department.unique()

# %%
# used to group large amounts of data and compute operations on these groups.
df.groupby('left').mean()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9384\3972386847.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('left').mean()
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
pd.crosstab(df.salary, df.left).plot(kind='bar')
plt.grid()

# %%
pd.crosstab(df.Department, df.left).plot(kind='bar')
plt.grid()

# %% [markdown]
# From the data analysis so far we can conclude that we will use following variables as independant variables in our model
# 1. Satisfaction Level
# 2. Average Monthly Hours
# 3. Promotion Last 5 Years
# 4. Salary

# %%
subdf = df[['satisfaction_level', 'average_montly_hours', 'promotion_last_5years', 'salary']]
subdf.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low

# %%
# df.drop_duplicates(subset=['Department'])
