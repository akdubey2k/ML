# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

# %%
# %matplotlib inline
def gradient_descent(x, y):
    m_curr = b_curr = 0
    learning_rate = 0.08
    iteration = 1000
    n = len(x)
    
    import math
    mse_old = 0.0
    
    plt.scatter(x, y, color='red', marker='+', linewidths=10)
    plt.xlabel('x', fontsize=20)
    plt.ylabel('y', fontsize=20)
    plt.grid()
    
    for i in range(iteration):
        y_pred = m_curr * x + b_curr
        plt.plot(x, y_pred, color='green')
        
        mse = (1/n) * sum([val ** 2 for val in (y - y_pred)])
        if(math.isclose(mse_old, mse, abs_tol=0.0001)):
            break
        mse_old = mse
        md = (-2/n) * sum(x * (y - y_pred))
        bd = -(2/n) * sum(y - y_pred)
        
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print("m {}, b {}, mse {}, iter {}".format(m_curr, b_curr, mse, i))
    plt.plot(x, y_pred, color='blue')

# %%
gradient_descent(x, y)
# Out:
# m 4.96, b 1.44, mse 89.0, iter 0
# m 0.4991999999999983, b 0.26879999999999993, mse 71.10560000000002, iter 1
# m 4.451584000000002, b 1.426176000000001, mse 56.8297702400001, iter 2
# m 0.892231679999997, b 0.5012275199999995, mse 45.43965675929613, iter 3
# m 4.041314713600002, b 1.432759910400001, mse 36.35088701894832, iter 4
# m 1.2008760606719973, b 0.7036872622079998, mse 29.097483330142282, iter 5
# m 3.7095643080294423, b 1.4546767911321612, mse 23.307872849944438, iter 6
# m 1.4424862661541864, b 0.881337636696883, mse 18.685758762535738, iter 7
# m 3.4406683721083144, b 1.4879302070713722, mse 14.994867596913156, iter 8
# m 1.6308855378034224, b 1.0383405553279617, mse 12.046787238456794, iter 9
# m 3.2221235247119777, b 1.5293810083298451, mse 9.691269350698109, iter 10
# m 1.7770832372205707, b 1.1780607551353204, mse 7.8084968312098315, iter 11
# m 3.0439475772474127, b 1.5765710804477953, mse 6.302918117062937, iter 12
# m 1.8898457226770244, b 1.3032248704973899, mse 5.098330841763168, iter 13
# m 2.898169312926714, b 1.6275829443328358, mse 4.133961682056365, iter 14
# m 1.9761515088959358, b 1.4160484030347593, mse 3.361340532576948, iter 15
# m 2.7784216197824048, b 1.6809279342791488, mse 2.741808050753047, iter 16
# m 2.0415541605113807, b 1.5183370872989306, mse 2.244528230107478, iter 17
# m 2.6796170361078637, b 1.735457156285639, mse 1.8449036666988363, iter 18
# m 2.090471617540917, b 1.611567833948162, mse 1.5233119201782324, iter 19
# m 2.5976890103737853, b 1.790290604096816, mse 1.2640979056612756, iter 20
# m 2.1264168621494517, b 1.6969533824619085, mse 1.0547704368105268, iter 21
# m 2.529385561184701, b 1.8447607474362664, mse 0.8853615531285766, iter 22
# m 2.1521818147302194, b 1.7754939584778073, mse 0.7479156468369821, iter 23
# m 2.472104720735685, b 1.8983676540508527, mse 0.6360820885229722, iter 24
# m 2.1699839382964696, b 1.8480185634495874, mse 0.5447903801652151, iter 25
# m 2.423763296438881, b 1.950743302915348, mse 0.4699911136477278, iter 26
# m 2.1815831093070837, b 1.9152179921582295, mse 0.4084494012702221, iter 27
# m 2.3826922006906663, b 2.0016232209455125, mse 0.35758014655339476, iter 28
# m 2.1883747814212473, b 1.9776712492627107, mse 0.31531667795040486, iter 29
# m 2.3475529664737507, b 2.0508239542984783, mse 0.280005985849834, iter 30
# m 2.19146424741668, b 2.0358666977033213, mse 0.2503251729489924, iter 31
# m 2.317271157065729, b 2.0982251873107836, mse 0.2252148202231392, iter 32
# m 2.19172583072087, b 2.0902190019495084, mse 0.2038258415569305, iter 33
# m 2.2909832477163747, b 2.1437555628915694, mse 0.1854770944836773, iter 34
# m 2.1898500615476015, b 2.1410827139250586, mse 0.16962156815305135, iter 35
# m 2.2679942505397945, b 2.1873814501542004, mse 0.15581941113049289, iter 36
# m 2.1863812735157397, b 2.188763177870427, mse 0.14371641365577967, iter 37
# m 2.247743906750233, b 2.2290980581236037, mse 0.13302683968149862, iter 38
# m 2.181747562970493, b 2.2335252935837153, mse 0.1235197278285518, iter 39
# m 2.2297797112222417, b 2.268922416384484, mse 0.11500795886067308, iter 40
# m 2.176284659606544, b 2.2756005683762908, mse 0.1073395295828815, iter 41
# m 2.213735385878407, b 2.306887840824943, mse 0.10039058653754176, iter 42
# m 2.170254943136438, b 2.315192801071317, mse 0.09405986334903649, iter 43
# m 2.1993136987020745, b 2.3430395801944157, mse 0.08826423771269985, iter 44
# m 2.1638625904931037, b 2.3524826719863134, mse 0.08293518155053264, iter 45
# m 2.1862727486718105, b 2.3774314010318136, mse 0.07801592372722821, iter 46
# m 2.1572656385141533, b 2.3876314575042543, mse 0.07345918129710392, iter 47
# m 2.1744150151272015, b 2.4101229178167802, mse 0.06922534441882239, iter 48
# m 2.150585587951272, b 2.4207840437050385, mse 0.06528102333197575, iter 49
# m 2.1635786121786147, b 2.441177514495622, mse 0.06159788433500965, iter 50
# m 2.1439150477863547, b 2.4520713783305874, mse 0.05815171649232756, iter 51
# m 2.153630302083688, b 2.470660734860243, mse 0.054921682590988646, iter 52
# m 2.137323817683481, b 2.4816124722824338, mse 0.05188971727120564, iter 53
# m 2.1444599118649865, b 2.4986390442291735, mse 0.04904004275389065, iter 54
# m 2.1308637257526066, b 2.509516039457312, mse 0.04635877856867898, iter 55
# m 2.1359758694885094, b 2.525178884782891, mse 0.04383362645496491, iter 56
# m 2.124572474492945, b 2.535881845863144, mse 0.04145361541183607, iter 57
# m 2.128101633371053, b 2.5503459627684273, mse 0.03920889490609494, iter 58
# m 2.118476696509155, b 2.5608018247073736, mse 0.03709056666678448, iter 59
# m 2.120772834793503, b 2.5742047184297996, mse 0.03509054742420437, iter 60
# m 2.112594380710634, b 2.5843610027801502, mse 0.03320145649050715, iter 61
# m 2.1139349893254455, b 2.5968179395942217, mse 0.03141652330669783, iter 62
# m 2.1069367971074353, b 2.606638274382932, mse 0.0297295110602709, iter 63
# m 2.1075416624945413, b 2.618246487870094, mse 0.0281346532591438, iter 64
# m 2.1015100223265035, b 2.6277070518134993, mse 0.02662660077102551, iter 65
# m 2.101552998161378, b 2.6385491128066176, mse 0.025200377334927134, iter 66
# m 2.096316147250177, b 2.6476358156400974, mse 0.023851341948628327, iter 67
# m 2.095934536582619, b 2.657782334457597, mse 0.022575156852933542, iter 68
# m 2.0913542316575633, b 2.6664885833847243, mse 0.021367760086655644, iter 69
# m 2.090656263915584, b 2.676000378847538, mse 0.020225341788425083, iter 70
# m 2.0866210575773376, b 2.6843253115524512, mse 0.019144323582910155, iter 71
# m 2.0856918466960472, b 2.693255154066937, mse 0.018121340518098442, iter 72
# m 2.082111722558874, b 2.7012022430021245, mse 0.017153225123473996, iter 73
# m 2.0810180142142363, b 2.709596257293525, mse 0.01623699324146153, iter 74
# m 2.077820105696288, b 2.717172209303728, mse 0.015369831350564987, iter 75
# m 2.0766140592050317, b 2.7250710050809133, mse 0.014549085151541019, iter 76
# m 2.0737392325653374, b 2.732284895849552, mse 0.013772249230347736, iter 77
# m 2.0724614332425584, b 2.7397244808822614, mse 0.013036957645638886, iter 78
# m 2.0698615599121704, b 2.7465870759846718, mse 0.012340975315898037, iter 79
# m 2.0685434179941087, b 2.7535995950692826, mse 0.011682190103287127, iter 80
# m 2.066179196691222, b 2.760122819221025, mse 0.011058605508984853, iter 81
# m 2.064844857288579, b 2.7667371537338745, mse 0.010468333909073289, iter 82
# m 2.0626840746684203, b 2.7729336776379365, mse 0.009909590271584152, iter 83
# m 2.061351937985791, b 2.7791759333750248, mse 0.009380686304666458, iter 84
# m 2.0593680791107873, b 2.785058853801841, mse 0.00888002499345325, iter 85
# m 2.0580520100509183, b 2.7909527592203687, mse 0.00840609548939642, iter 86
# m 2.056223147935525, b 2.7965353529206687, mse 0.007957468320912865, iter 87
# m 2.05493343816708, b 2.8021025854443096, mse 0.007532790898352296, iter 88
# m 2.0532413459797505, b 2.8073981214530215, mse 0.007130783289727114, iter 89
# m 2.0519854787579397, b 2.812658575950258, mse 0.0067502342464980354, iter 90
# m 2.050414919687842, b 2.8176801739944057, mse 0.006389997461079277, iter 91
# m 2.0491981775199255, b 2.8226521847051367, mse 0.006048988039717134, iter 92
# m 2.047736336426391, b 2.8274127099427506, mse 0.005726179176078216, iter 93
# m 2.0465622835434223, b 2.8321132348672426, mse 0.005420599012302664, iter 94
# m 2.045198311770722, b 2.836625221187641, mse 0.005131327675503935, iter 95
# m 2.0440691768841837, b 2.8410699961476715, mse 0.0048574944787420265, iter 96
# m 2.042793827417138, b 2.845345591859636, mse 0.004598275276411798, iter 97
# m 2.0417108070703494, b 2.8495492600018677, mse 0.004352889964781892, iter 98
# m 2.0405161418256377, b 2.8536001910078013, mse 0.004120600119124239, iter 99
# m 2.0394796405287705, b 2.8575764123702467, mse 0.003900706759494166, iter 100
# m 2.038358795260416, b 2.8614139589371974, mse 0.0036925482377773012, iter 101
# m 2.0373686153122295, b 2.8651755037822464, mse 0.003495498239118547, iter 102
# m 2.0363156105472275, b 2.8688104878272167, mse 0.003308963891300129, iter 103
# m 2.0353711018270433, b 2.872369316712193, mse 0.0031323839760444175, iter 104
# m 2.0343806905895945, b 2.875812097161261, mse 0.0029652272365934215, iter 105
# m 2.033480868514503, b 2.879179430132454, mse 0.0028069907762599973, iter 106
# m 2.0325484134654004, b 2.8824399044243, mse 0.0026571985429625707, iter 107
# m 2.0316920516426316, b 2.88562628125302, mse 0.00251539989504975, iter 108
# m 2.030813425750151, b 2.8887138914640733, mse 0.0023811682439901036, iter 109
# m 2.0299991285271304, b 2.8917292244697492, mse 0.0022540997697606665, iter 110
# m 2.029170634573901, b 2.8946529668615666, mse 0.00213381220499766, iter 111
# m 2.0283968936302834, b 2.8975065875682433, mse 0.002019943684199672, iter 112
# m 2.027615198808228, b 2.9002750246147886, mse 0.001912151654475956, iter 113
# m 2.026880437090648, b 2.902975725248473, mse 0.0018101118445290139, iter 114
