# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('homeprice.csv')
df
# Out:
#    area   price
# 0  1200  550000
# 1  1600  590000
# 2  2000  600000
# 3  2600  640000
# 4  3200  700000
# 5  3800  745000
# 6  4400  750000
# 7  4800  820000

# %%
plt.xlabel('area (sq.ft.)', fontsize=11)
plt.ylabel('price ($)', fontsize=11)
plt.scatter(df.area, df.price, color='blue', marker='+')

# %%
model = linear_model.LinearRegression()
model.fit(df[['area']], df.price)
model.predict([[3300]])
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([698999.5908347])

# %%
p = model.predict(df[['area']])
p
# Out:
# array([551252.04582651, 579394.43535188, 607536.82487725, 649750.4091653 ,
#        691963.99345336, 734177.57774141, 776391.16202946, 804533.55155483])

# %%
plt.xlabel('area (sq.ft.)', fontsize=11)
plt.ylabel('price ($)', fontsize=11)
plt.scatter(df.area, df.price, color='blue', marker='+')
plt.plot(df.area, p, color='orange')
plt.plot(df.area, df.price, color='gray')

# %%
new_df = df.drop('price', axis='columns')
new_df
# Out:
#    area
# 0  1200
# 1  1600
# 2  2000
# 3  2600
# 4  3200
# 5  3800
# 6  4400
# 7  4800

# %%
new_df['price'] = p
new_df
# Out:
#    area          price
# 0  1200  551252.045827
# 1  1600  579394.435352
# 2  2000  607536.824877
# 3  2600  649750.409165
# 4  3200  691963.993453
# 5  3800  734177.577741
# 6  4400  776391.162029
# 7  4800  804533.551555

# %%
new_df.to_csv('price_prediction.csv', index=False)
