# %% [markdown]
# #### Exercise
# Use iris flower dataset from sklearn library and use cross_val_score against following models to measure the performance of each. In the end figure out the model with best performance,
#
# 1. Logistic Regression
# 2. SVM
# 3. Decision Tree
# 4. Random Forest

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
iris_data = load_iris()
dir(iris_data)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
from sklearn.model_selection import cross_val_score
lr_score = cross_val_score(LogisticRegression(solver='lbfgs', max_iter=1000, dual=False), iris_data.data, iris_data.target)
print("LR values: ", lr_score)
print("LR Score: ", lr_score.mean())
# Out:
# LR values:  [0.96666667 1.         0.93333333 0.96666667 1.        ]
# LR Score:  0.9733333333333334

# %%
lr_score = cross_val_score(SVC(), iris_data.data, iris_data.target)
print("SVM values: ", lr_score)
print("SVM Score: ", lr_score.mean())
# Out:
# SVM values:  [0.96666667 0.96666667 0.96666667 0.93333333 1.        ]
# SVM Score:  0.9666666666666666

# %%
lr_score = cross_val_score(DecisionTreeClassifier(), iris_data.data, iris_data.target)
print("DT values: ", lr_score)
print("DT Score: ", lr_score.mean())
# Out:
# DT values:  [0.96666667 0.96666667 0.9        0.96666667 1.        ]
# DT Score:  0.9600000000000002

# %%
lr_score = cross_val_score(RandomForestClassifier(n_estimators=50), iris_data.data, iris_data.target)
print("RF values: ", lr_score)
print("RF Score: ", lr_score.mean())
# Out:
# RF values:  [0.96666667 0.96666667 0.93333333 0.9        1.        ]
# RF Score:  0.9533333333333334
