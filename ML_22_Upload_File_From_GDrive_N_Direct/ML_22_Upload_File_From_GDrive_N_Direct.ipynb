# %%
# !pip install -q kaggle

# %%
# from google.colab import files
# files.upload()

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ## the below line of source code is asking to upload a "kaggle.json" file.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# https://colab.research.google.com/github/corrieann/kaggle/blob/master/kaggle_api_in_colab.ipynb#scrollTo=L7ZmFbHybsPk
# !pip install -q kaggle
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-49ed3c3f-e30f-410e-9ce4-f588d572d70d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49ed3c3f-e30f-410e-9ce4-f588d572d70d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle competitions list
# Out:
# ref                                                                                     deadline             category             reward  teamCount  userHasEntered
# --------------------------------------------------------------------------------------  -------------------  ---------------  ----------  ---------  --------------
# https://www.kaggle.com/competitions/arc-prize-2024                                      2024-11-10 23:59:00  Featured         $1,100,000        155           False
# https://www.kaggle.com/competitions/ai-mathematical-olympiad-prize                      2024-06-27 23:59:00  Featured         $1,048,576       1288           False
# https://www.kaggle.com/competitions/lmsys-chatbot-arena                                 2024-08-05 23:59:00  Research           $100,000        799           False
# https://www.kaggle.com/competitions/learning-agency-lab-automated-essay-scoring-2       2024-07-02 23:59:00  Featured            $50,000       2534           False
# ...

# %%
# !kaggle datasets list
# Out:
# ref                                                                  title                                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# shreyanshverma27/online-sales-dataset-popular-marketplace-data       Online Sales Dataset - Popular Marketplace Data    7KB  2024-05-25 23:55:26           9353        166  1.0
# teocalvo/teomewhy-loyalty-system                                     TeoMeWhy Loyalty System                           23MB  2024-06-20 11:05:17            272        404  1.0
# zeesolver/data-eng-salary-2024                                       Data Developer Salary in 2024💰                   108KB  2024-06-10 07:33:22           1494         25  1.0
# ...

# %%
# !kaggle datasets download "gargmanas/pima-indians-diabetes"
# https://www.kaggle.com/datasets/gargmanas/pima-indians-diabetes
# !kaggle datasets download "yapwh1208/supermarket-sales-data"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/gargmanas/pima-indians-diabetes
# License(s): GPL-2.0
# pima-indians-diabetes.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# ## In the below image shows that the "pima-indians-diabetes.zip" is already present in the google drive folder.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  ### While unzip the "pima-indians-diabetes.zip" which is already present then  re-running the code it will ask for replacement.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !unzip pima-indians-diabetes.zip
# !unzip supermarket-sales-data.zip
# Out:
# Archive:  pima-indians-diabetes.zip
# replace pima-indians-diabetes.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# https://drive.google.com/file/d/1Tvb4nMzxpJF3JnNbZoVCzpYQKEey2ARc/view?usp=sharing
# file_id='1Tvb4nMzxpJF3JnNbZoVCzpYQKEey2ARc'
# link = f'https://drive.google.com/uc?id=1Tvb4nMzxpJF3JnNbZoVCzpYQKEey2ARc'
link = "/content/pima-indians-diabetes.csv"

# %%
import pandas as pd
df = pd.read_csv(link)
# df = pd.read_csv('/content/pima-indians-diabetes.csv')

df.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
df.isnull().sum()
# Out:
# 6        0
# 148      0
# 72       0
# 35       0
# 0        0
# 33.6     0
# 0.627    0
# 50       0
# 1        0
# dtype: int64

# %%
df.describe()
# Out:
#                 6         148          72          35           0        33.6  \
# count  767.000000  767.000000  767.000000  767.000000  767.000000  767.000000
# mean     3.842243  120.859192   69.101695   20.517601   79.903520   31.990482
# std      3.370877   31.978468   19.368155   15.954059  115.283105    7.889091
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   32.000000   32.000000
# 75%      6.000000  140.000000   80.000000   32.000000  127.500000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#             0.627          50           1
# count  767.000000  767.000000  767.000000
# mean     0.471674   33.219035    0.348110
# std      0.331497   11.752296    0.476682
# min      0.078000   21.000000    0.000000
# 25%      0.243500   24.000000    0.000000
# ...
