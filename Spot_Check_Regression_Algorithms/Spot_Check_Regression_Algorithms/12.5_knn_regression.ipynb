# %% [markdown]
# ## Import Libraries

# %%
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsRegressor
import numpy as np
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Reference
# * [Boston House Prices Dataset](https://www.kaggle.com/datasets/vikrishnan/boston-house-prices)
# * [Boston House Prices Dataset](https://www.kaggle.com/code/prasadperera/the-boston-housing-dataset)
# * [sklearn.model_selection.KFold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html)
# * [sklearn.neighbors.KNeighborsRegressor](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html)
# * [pandas.DataFrame.values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.values.html)
# * [pandas.DataFrame.to_numpy](https://pandas.pydata.org/pandas-docs/version/1.5/reference/api/pandas.DataFrame.to_numpy.html)
# * [sklearn.model_selection.cross_val_score](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html)

# %% [markdown]
# ## Data Extraction and Cleaning

# %%
data = read_csv('housing.csv', delim_whitespace=True)
# data

# %%
# print('data.shape :=>\n ', data.shape, '\n' + '-'*80, '\n')
# # executing right to left, first print info and then print statement
# print('data.info() :=>\n ', data.info(), '\n' + '-'*80, '\n')
# print('data.isnull().sum() :=>\n ', data.isnull().sum(), '\n' + '-'*80, '\n')

# %%
# array = data.values
# array

# %% [markdown]
# ## Data Pre-processing

# %%
array = data.to_numpy()
# print('array :=>\n ', array, '\n' + '-'*80, '\n')
X = array[:, 0:13]
# print('X :=>\n ', X, '\n' + '-'*80, '\n')
y = array[:, 13]
# print('y :=>\n ', y, '\n' + '-'*80, '\n')

# %% [markdown]
# ## Data Classification and Model Selection

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=7)
# print('kfold :=>\n ', kfold, '\n' + '-'*80, '\n')
# knn_model = KNeighborsRegressor(n_neighbors=7, weights='distance', n_jobs=-1)
knn_model = KNeighborsRegressor(weights='distance', n_jobs=-1)
# knn_model = KNeighborsRegressor(n_jobs=-1)
# print('knn_model :=>\n ', knn_model, '\n' + '-'*80, '\n')

# %% [markdown]
# ## Data Scrubbing and Error Estimation

# %%
scoring = 'neg_mean_squared_error'
results = cross_val_score(knn_model, X, y, scoring=scoring, cv=kfold)
# print('results :=>\n ', results, '\n' + '-'*80, '\n')
print('results.mean() :=>\n ', results.mean(), '\n' + '-'*80, '\n')
# Out:
# results.mean() :=>
#   -35.94513544756194
# --------------------------------------------------------------------------------
