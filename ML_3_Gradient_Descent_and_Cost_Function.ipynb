# %% [markdown]
# **Thanks to:**
# * [Gradient Descent and Cost Function](https://www.youtube.com/watch?v=vsWrXfO3wWw&list=PLeo1K3hjS3uvCeTYTeyfe0-rN5r8zn9rw&index=4)
# * [Gradient Descent Algorithm](https://www.analyticsvidhya.com/blog/2020/10/how-does-the-gradient-descent-algorithm-work-in-machine-learning/)
# * [Fighting Overfitting With L1 or L2 Regularization](https://neptune.ai/blog/fighting-overfitting-with-l1-or-l2-regularization)
# * [Mean Squared Error](https://www.ml-science.com/mean-squared-error)

# %% [markdown]
# # 1. Description
# ## 1.1 Gradient Descent without regularization
# **Gradient Descent** is a first-order optimization algorithm. It involves taking steps in the opposite direction of the gradient in order to find the **global minimum** (or *local minimum in non-convex functions*) of the objective function.<br>
# The image below provides a great illustration of how **Gradient Descent** takes steps towards the **global minimum** of a convex function.
# ##### <br>
# By iteratively updating the model’s parameters in the *negative gradient direction,* **gradient descent** *gradually converges towards the optimal set of parameters that yields the* **lowest cost.** <br>
# The **learning rate,** a **hyperparameter,** determines the **step size** taken in each iteration, influencing the speed and stability of convergence.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1.2 Mean Squared Error (MSE)
# **Mean squared error (MSE)** measures error in statistical models by using the *average squared difference between **observed** and **predicted** values.*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd

# %%
def mse(y_true, y_pred):

  # determine the cost
  mse = sum([val **2 for val in (y_true - y_pred)]) / len(y_true)
  return mse

# %% [markdown]
# # Partial derivative of coefficient and intercept

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Learning rate change
# ![image.png](data:image/png;base64,...)

# %%
def gradient_descent(x, y):

  m_curr = b_curr = mse_old = 0.0
  iterations = 10000
  n = len(x)
  y_true = y

  learning_rate = 0.08

  for i in range(iterations):

    y_pred = m_curr * x + b_curr
    plt.plot(x, y_pred, color='green')

    mse = (1/n) * np.sum((y_true - y_pred) ** 2)

    if(math.isclose(mse_old, mse, abs_tol=0.001)):
      break
    mse_old = mse

    part_mCurr = (-2/n)*sum(x * (y_true - y_pred))
    part_bCurr = (-2/n)*sum(y_true - y_pred)

    m_curr = m_curr - learning_rate * part_mCurr
    b_curr = b_curr - learning_rate * part_bCurr

    print('m {},b {},mse {},iteration {}'.format(m_curr, b_curr, mse, i))
  plt.plot(x, y_pred, color='blue')

# %% [markdown]
# https://raw.githubusercontent.com/akdubey2k/ML/main/3_gradient_descent_%26_cost_function/homeprices.csv

# %%
url = 'https://raw.githubusercontent.com/akdubey2k/ML/main/3_gradient_descent_%26_cost_function/homeprices.csv'
df = pd.read_csv(url)
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
from sklearn import linear_model

model = linear_model.LinearRegression()
model.fit(df[['area']], df.price)
plt.plot(df.area, model.predict(df[['area']]), color='blue')
plt.xlabel('area', fontsize=12)
plt.ylabel('price', fontsize=12)
plt.scatter(df.area, df.price, marker='+', color='purple')
plt.grid()
plt.title('area vs price', fontsize=18)
# Out:
# Text(0.5, 1.0, 'area vs price')

# %%
df.area
np.array(df.area)
# Out:
# array([2600, 3000, 3200, 3600, 4000])

# %%
df.price
np.array(df.price)
# Out:
# array([550000, 565000, 610000, 680000, 725000])

# %%
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])
y
# Out:
# array([ 5,  7,  9, 11, 13])

# %%
# %matplotlib inline
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.scatter(x, y, marker='+', color='orange', linewidths=15)
plt.grid()
plt.title('Linear Equation - Gradient Descent', fontsize=16)
plt.legend(title='linear equation')
gradient_descent(x, y)
#gradient_descent(np.array(df.area), np.array(df.price))
# Out:
# No handles with labels found to put in legend.
# m 4.96,b 1.44,mse 89.0,iteration 0
# m 0.4991999999999983,b 0.26879999999999993,mse 71.10560000000002,iteration 1
# m 4.451584000000002,b 1.426176000000001,mse 56.8297702400001,iteration 2
# m 0.892231679999997,b 0.5012275199999995,mse 45.43965675929613,iteration 3
# m 4.041314713600002,b 1.432759910400001,mse 36.35088701894832,iteration 4
# m 1.2008760606719973,b 0.7036872622079998,mse 29.097483330142282,iteration 5
# m 3.7095643080294423,b 1.4546767911321612,mse 23.307872849944438,iteration 6
# m 1.4424862661541864,b 0.881337636696883,mse 18.685758762535738,iteration 7
# m 3.4406683721083144,b 1.4879302070713722,mse 14.994867596913156,iteration 8
# m 1.6308855378034224,b 1.0383405553279617,mse 12.046787238456794,iteration 9
# m 3.2221235247119777,b 1.5293810083298451,mse 9.691269350698109,iteration 10
# m 1.7770832372205707,b 1.1780607551353204,mse 7.8084968312098315,iteration 11
# m 3.0439475772474127,b 1.5765710804477953,mse 6.302918117062937,iteration 12
# m 1.8898457226770244,b 1.3032248704973899,mse 5.098330841763168,iteration 13
# m 2.898169312926714,b 1.6275829443328358,mse 4.133961682056365,iteration 14
# m 1.9761515088959358,b 1.4160484030347593,mse 3.361340532576948,iteration 15
# m 2.7784216197824048,b 1.6809279342791488,mse 2.741808050753047,iteration 16
# m 2.0415541605113807,b 1.5183370872989306,mse 2.244528230107478,iteration 17
# m 2.6796170361078637,b 1.735457156285639,mse 1.8449036666988363,iteration 18
# m 2.090471617540917,b 1.611567833948162,mse 1.5233119201782324,iteration 19
# m 2.5976890103737853,b 1.790290604096816,mse 1.2640979056612756,iteration 20
# m 2.1264168621494517,b 1.6969533824619085,mse 1.0547704368105268,iteration 21
# m 2.529385561184701,b 1.8447607474362664,mse 0.8853615531285766,iteration 22
# m 2.1521818147302194,b 1.7754939584778073,mse 0.7479156468369821,iteration 23
# m 2.472104720735685,b 1.8983676540508527,mse 0.6360820885229722,iteration 24
# m 2.1699839382964696,b 1.8480185634495874,mse 0.5447903801652151,iteration 25
# m 2.423763296438881,b 1.950743302915348,mse 0.4699911136477278,iteration 26
# m 2.1815831093070837,b 1.9152179921582295,mse 0.4084494012702221,iteration 27
# m 2.3826922006906663,b 2.0016232209455125,mse 0.35758014655339476,iteration 28
# m 2.1883747814212473,b 1.9776712492627107,mse 0.31531667795040486,iteration 29
# m 2.3475529664737507,b 2.0508239542984783,mse 0.280005985849834,iteration 30
# m 2.19146424741668,b 2.0358666977033213,mse 0.2503251729489924,iteration 31
# m 2.317271157065729,b 2.0982251873107836,mse 0.2252148202231392,iteration 32
# m 2.19172583072087,b 2.0902190019495084,mse 0.2038258415569305,iteration 33
# m 2.2909832477163747,b 2.1437555628915694,mse 0.1854770944836773,iteration 34
# m 2.1898500615476015,b 2.1410827139250586,mse 0.16962156815305135,iteration 35
# m 2.2679942505397945,b 2.1873814501542004,mse 0.15581941113049289,iteration 36
# m 2.1863812735157397,b 2.188763177870427,mse 0.14371641365577967,iteration 37
# m 2.247743906750233,b 2.2290980581236037,mse 0.13302683968149862,iteration 38
# m 2.181747562970493,b 2.2335252935837153,mse 0.1235197278285518,iteration 39
# m 2.2297797112222417,b 2.268922416384484,mse 0.11500795886067308,iteration 40
# m 2.176284659606544,b 2.2756005683762908,mse 0.1073395295828815,iteration 41
# m 2.213735385878407,b 2.306887840824943,mse 0.10039058653754176,iteration 42
# m 2.170254943136438,b 2.315192801071317,mse 0.09405986334903649,iteration 43
# m 2.1993136987020745,b 2.3430395801944157,mse 0.08826423771269985,iteration 44
# m 2.1638625904931037,b 2.3524826719863134,mse 0.08293518155053264,iteration 45
# m 2.1862727486718105,b 2.3774314010318136,mse 0.07801592372722821,iteration 46
# m 2.1572656385141533,b 2.3876314575042543,mse 0.07345918129710392,iteration 47
# m 2.1744150151272015,b 2.4101229178167802,mse 0.06922534441882239,iteration 48
# m 2.150585587951272,b 2.4207840437050385,mse 0.06528102333197575,iteration 49
# m 2.1635786121786147,b 2.441177514495622,mse 0.06159788433500965,iteration 50
# m 2.1439150477863547,b 2.4520713783305874,mse 0.05815171649232756,iteration 51
# m 2.153630302083688,b 2.470660734860243,mse 0.054921682590988646,iteration 52
# m 2.137323817683481,b 2.4816124722824338,mse 0.05188971727120564,iteration 53
# m 2.1444599118649865,b 2.4986390442291735,mse 0.04904004275389065,iteration 54
# m 2.1308637257526066,b 2.509516039457312,mse 0.04635877856867898,iteration 55
# m 2.1359758694885094,b 2.525178884782891,mse 0.04383362645496491,iteration 56
# m 2.124572474492945,b 2.535881845863144,mse 0.04145361541183607,iteration 57
# m 2.128101633371053,b 2.5503459627684273,mse 0.03920889490609494,iteration 58
# m 2.118476696509155,b 2.5608018247073736,mse 0.03709056666678448,iteration 59
# m 2.120772834793503,b 2.5742047184297996,mse 0.03509054742420437,iteration 60
# m 2.112594380710634,b 2.5843610027801502,mse 0.03320145649050715,iteration 61
# m 2.1139349893254455,b 2.5968179395942217,mse 0.03141652330669783,iteration 62
# m 2.1069367971074353,b 2.606638274382932,mse 0.0297295110602709,iteration 63
# m 2.1075416624945413,b 2.618246487870094,mse 0.0281346532591438,iteration 64
# m 2.1015100223265035,b 2.6277070518134993,mse 0.02662660077102551,iteration 65
# m 2.101552998161378,b 2.6385491128066176,mse 0.025200377334927134,iteration 66
# m 2.096316147250177,b 2.6476358156400974,mse 0.023851341948628327,iteration 67
# m 2.095934536582619,b 2.657782334457597,mse 0.022575156852933542,iteration 68
# m 2.0913542316575633,b 2.6664885833847243,mse 0.021367760086655644,iteration 69
# m 2.090656263915584,b 2.676000378847538,mse 0.020225341788425083,iteration 70
# m 2.0866210575773376,b 2.6843253115524512,mse 0.019144323582910155,iteration 71
# m 2.0856918466960472,b 2.693255154066937,mse 0.018121340518098442,iteration 72
